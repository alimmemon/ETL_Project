# %%
import sqlalchemy
import pandas as pd
from sqlalchemy import create_engine
from credentials import username
from credentials import password
from  psycopg2 import connect

# %%
import_ = 'usretechnicalpotential(clean).csv'
df = pd.read_csv(import_)
df.head()
# Out:
#         State  Urban_Solar  Rural_Solar  Rooftop_Solar  CSP_Solar  \
# 0     Alabama        35850      3706838        15475.0          0
# 1      Alaska          166      8282976            0.0          0
# 2     Arizona       121305     11867693        22736.0   12544333
# 3    Arkansas        28960      4986388         8484.0          0
# 4  California       246008      8855917       106411.0    8490916
#
#    Onshore_Wind  Offshore_Wind  Biopower_Solid  Biopower_Gaseous  \
# 0           283            0.0           11193              1533
# 1       1373433            0.0             513                61
# 2         26036            0.0            1087               837
# 3         22892            0.0           14381              1063
# 4         89862      2662579.0           12408             15510
#
#    Geothermal_Hydrothermal  EGS_Geothermal  Hydropower
# 0                        0        535489.0        4102
# 1                    15437             0.0       23675
# ...

# %%
rds_connection_string = f'{username}:{password}@localhost:5433/etl_db'
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()
#df.to_sql(name='state_energy', con=engine, if_exists='append', index=False)
# Out:
# ['state_energy']

# %%
pd.read_sql_query('select * from state_energy', con=engine).head()
# Out:
#         State  Urban_Solar  Rural_Solar  Rooftop_Solar  CSP_Solar  \
# 0     Alabama        35850      3706838        15475.0          0
# 1      Alaska          166      8282976            0.0          0
# 2     Arizona       121305     11867693        22736.0   12544333
# 3    Arkansas        28960      4986388         8484.0          0
# 4  California       246008      8855917       106411.0    8490916
#
#    Onshore_Wind  Offshore_Wind  Biopower_Solid  Biopower_Gaseous  \
# 0           283            0.0           11193              1533
# 1       1373433            0.0             513                61
# 2         26036            0.0            1087               837
# 3         22892            0.0           14381              1063
# 4         89862      2662579.0           12408             15510
#
#    Geothermal_Hydrothermal  EGS_Geothermal  Hydropower
# 0                        0        535489.0        4102
# 1                    15437             0.0       23675
# ...
